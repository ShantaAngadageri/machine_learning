# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn.metrics import mean_squared_error
from math import sqrt
# %matplotlib inline

# %%
data=pd.read_csv("D:/ML_datasets/Salary_dataset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
train, test= train_test_split(data, test_size=0.3)

# %%
x_train= train.drop('Salary' , axis=1)
y_train= train['Salary']

# %%
plt.scatter(x_train.iloc[:,1]  , y_train, color="red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("YearsExperience vs Salary")
plt.show()

# %%
x_test = test.drop('Salary', axis=1)
y_test = test['Salary']

# %%
model= neighbors.KNeighborsRegressor(n_neighbors=3)

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
pred=model.predict(x_test)
pred
# Out:
# array([ 58698.66666667, 113756.33333333, 113756.33333333,  91193.        ,
#         57994.66666667,  60186.66666667, 106899.66666667,  63683.66666667,
#        113756.33333333])

# %%
mse=sqrt(mean_squared_error(y_test, pred))
mse
# Out:
# 3847.7513282371333
